# %% [markdown]
# # Top 5 Automated EDA Libraries

# %%
import pandas as pd
import seaborn as sns

# %% [markdown]
# # 1. sweetviz

# %%
# !pip install sweetviz

# %%
import sweetviz as sv

# %%
df=sns.load_dataset('titanic')

# %%
df.tail()
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked   class  \
# 886         0       2    male  27.0      0      0  13.00        S  Second
# 887         1       1  female  19.0      0      0  30.00        S   First
# 888         0       3  female   NaN      1      2  23.45        S   Third
# 889         1       1    male  26.0      0      0  30.00        C   First
# 890         0       3    male  32.0      0      0   7.75        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True

# %%
df.shape
# Out:
# (891, 15)

# %%
my_report= sv.analyze([df,'Data'], target_feat='survived')
# Out:
#                                              |          | [  0%]   00:00 -> (? left)

# %%
my_report.show_html('Report.html')
# Out:
# Report Report.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %%
my_class=sv.analyze([df,'Data'], target_feat='alone')
# Out:
#                                              |          | [  0%]   00:00 -> (? left)

# %%
my_class.show_html('Report1.html')
# Out:
# Report Report1.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %% [markdown]
# # 2. dtale

# %%
# !pip install dtale

# %%
import dtale

# %%
df=sns.load_dataset('titanic')

# %%
d = dtale.show(df)
d
# Out:
#         <iframe
#             width="100%"
#             height="475"
#             src="http://localhost:40000/dtale/iframe/1"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# # 3. dabl

# %%
# !pip install dabl

# %%
import dabl

# %%
df=sns.load_dataset('titanic')

# %%
dabl.clean(df)
# Out:
#     survived pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0          0      3    male  22.0      1      0   7.2500        S   Third
# 1          1      1  female  38.0      1      0  71.2833        C   First
# 2          1      3  female  26.0      0      0   7.9250        S   Third
# 3          1      1  female  35.0      1      0  53.1000        S   First
# 4          0      3    male  35.0      0      0   8.0500        S   Third
# ..       ...    ...     ...   ...    ...    ...      ...      ...     ...
# 886        0      2    male  27.0      0      0  13.0000        S  Second
# 887        1      1  female  19.0      0      0  30.0000        S   First
# 888        0      3  female   NaN      1      2  23.4500        S   Third
# 889        1      1    male  26.0      0      0  30.0000        C   First
# 890        0      3    male  32.0      0      0   7.7500        Q   Third
#
#        who adult_male deck  embark_town alive  alone
# ...

# %%
dabl.plot(df, 'pclass')
# Out:
# /Users/Raazia/opt/anaconda3/lib/python3.7/site-packages/dabl/plot/supervised.py:547: FutureWarning:
#
# The second positional argument of plot is a Series 'y'. If passing a column name, use a keyword.
# Target looks like classification
# Linear Discriminant Analysis training set score: 0.533
# /Users/Raazia/opt/anaconda3/lib/python3.7/site-packages/dabl/plot/utils.py:376: UserWarning:
#
# FixedFormatter should only be used together with FixedLocator
#
# /Users/Raazia/opt/anaconda3/lib/python3.7/site-packages/dabl/plot/utils.py:376: UserWarning:
#
# FixedFormatter should only be used together with FixedLocator
#
# /Users/Raazia/opt/anaconda3/lib/python3.7/site-packages/dabl/plot/utils.py:376: UserWarning:
#
# FixedFormatter should only be used together with FixedLocator
#
# /Users/Raazia/opt/anaconda3/lib/python3.7/site-packages/dabl/plot/utils.py:376: UserWarning:
#
# FixedFormatter should only be used together with FixedLocator
#
# ...

# %% [markdown]
# # 4. pandas-profiling

# %%
# !pip install pandas-profiling

# %%
import pandas_profiling

# %%
tips=sns.load_dataset('tips')

# %%
#descriptive statistics
pandas_profiling.ProfileReport(tips)
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated with the `pandas-profiling` Python package&quot;&gt;&lt;meta name=author content=&quot;Simon Brugman and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling v2.8.0&quot;&gt;&lt;meta name=url content=https://github.com/pandas-profiling/pandas-profiling&gt;&lt;meta name=date content=&quot;2021-09-03 19:00:56.921216&quot;&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %% [markdown]
# # 5. autoviz

# %%
# !pip install autoviz

# %%
import autoviz

# %%
from autoviz.AutoViz_Class import AutoViz_Class
AV = AutoViz_Class()
tips = AV.AutoViz('tips.csv')
# Out:
# Shape of your Data Set: (244, 8)
# ############## C L A S S I F Y I N G  V A R I A B L E S  ####################
# Classifying variables in data set...
#     Number of Numeric Columns =  2
#     Number of Integer-Categorical Columns =  1
#     Number of String-Categorical Columns =  1
#     Number of Factor-Categorical Columns =  0
#     Number of String-Boolean Columns =  3
#     Number of Numeric-Boolean Columns =  0
#     Number of Discrete String Columns =  0
#     Number of NLP String Columns =  0
#     Number of Date Time Columns =  0
#     Number of ID Columns =  1
#     Number of Columns to Delete =  0
#     8 Predictors classified...
#         This does not include the Target column(s)
#         1 variables removed since they were ID or low-information variables
# Number of All Scatter Plots = 3
# Time to run AutoViz (in seconds) = 3.432
#
#  ###################### VISUALIZATION Completed ########################
